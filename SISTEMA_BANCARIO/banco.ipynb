# %%
nome = input("Escreva o seu nome: ").upper()
print(f"---------- SEJA BEM-VINDO AO BANCO DE EMPRESTIMOS, {nome}! ----------")
# Out:
# ---------- SEJA BEM-VINDO AO BANCO DE EMPRESTIMOS, MATHEUS! ----------

# %%
while True:
    escolha = input("Você quer fazer um emprestimo? S/N").lower()
    if escolha != "s": 
        print("")

# %%
score = input("Qual o seu score atual no banco?")
if score < 100: 
    print("Seu score não é suficiente para fazer um emprestimo")
