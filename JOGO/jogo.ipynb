# %%
print("Você foi preso injustamente!! \n")
print("Fuja da prisão sem ser visto! \n") 
print("Escreva direita ou esquerda para escolher seu caminho")
# Out:
# Você foi preso injustamente!!
#
# Fuja da prisão sem ser visto!
#
# Escreva direita ou esquerda para escolher seu caminho

# %%
caminho = input("Digite sua escolha: ").lower()

# %%
if caminho == "esquerda":
    print("Corredor limpo, siga em frente!")
elif caminho == "direita":
    print("este corredor tem um guarda!")
    print("Escolha uma opção: esconder ou lutar com o guarda")
    opcao = input("Digite sua escolha: ").lower()
    if opcao == "esconder": 
        print("O guarda foi embora e não te percebeu!")
    else: 
        print("O guarda tinha um taiser, você foi para a solitária")
# Out:
# este corredor tem um guarda!
# Escolha uma opção: esconder ou lutar com o guarda
# O guarda foi embora e não te percebeu!
